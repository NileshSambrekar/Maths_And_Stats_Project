# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Load the dataset
superstore_df=pd.read_excel('sample-superstore-subset-excel.xlsx')

# %%
# Display the first few rows and summary statistics

superstore_df.head(10)
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
# 5   23597         Medium      0.09       55.48          14.30            3
# 6   25549            Low      0.08      120.97          26.30            3
# 7   20228  Not Specified      0.02      500.98          26.00            5
# 8   19483            Low      0.08        6.48           6.81            5
# 9   24782           High      0.01       90.24           0.99            6
#
#      Customer Name       Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher     Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter     Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter     Express Air        Corporate       Technology  ...
# 5    Bonnie Potter     Express Air        Corporate  Office Supplies  ...
# 6    Bonnie Potter  Delivery Truck        Corporate       Technology  ...
# 7   Ronnie Proctor  Delivery Truck      Home Office        Furniture  ...
# 8   Ronnie Proctor     Regular Air      Home Office  Office Supplies  ...
# 9     Dwight Hwang     Regular Air      Home Office  Office Supplies  ...
#
#     Region State or Province         City  Postal Code Order Date  Ship Date  \
# 0  Central          Illinois      Addison        60101 2012-05-28 2012-05-30
# 1     West        Washington    Anacortes        98221 2010-07-07 2010-07-08
# 2     West        Washington    Anacortes        98221 2011-07-27 2011-07-28
# 3     West        Washington    Anacortes        98221 2011-07-27 2011-07-28
# 4     West        Washington    Anacortes        98221 2011-07-27 2011-07-27
# 5     West        Washington    Anacortes        98221 2011-11-09 2011-11-11
# 6     West        Washington    Anacortes        98221 2013-07-01 2013-07-08
# 7     West        California  San Gabriel        91776 2010-12-13 2010-12-15
# 8     West        California  San Gabriel        91776 2012-05-12 2012-05-21
# 9     West        California     San Jose        95123 2011-05-26 2011-05-26
#
#       Profit  Quantity ordered new    Sales Order ID
# 0     1.3200                     2     5.90    88525
# 1     4.5600                     4    13.01    88522
# 2   -47.6400                     7    49.92    88523
# 3   -30.5100                     7    41.64    88523
# 4   998.2023                     8  1446.67    88523
# 5  1388.0523                    37  2011.67    88524
# 6  1001.4453                    12  1451.37    88526
# 7  4390.3665                    12  6362.85    90193
# 8  -141.2600                    18   113.25    90197
# 9  1045.4673                    16  1515.17    90194
#
# [10 rows x 24 columns]

# %% [markdown]
# ## Understanding of data

# %%
#Number of rows and columns
superstore_df.shape
# Out:
# (9426, 24)

# %%
#knowing the data types for all columns
superstore_df.dtypes
# Out:
# Row ID                           int64
# Order Priority                  object
# Discount                       float64
# Unit Price                     float64
# Shipping Cost                  float64
# Customer ID                      int64
# Customer Name                   object
# Ship Mode                       object
# Customer Segment                object
# Product Category                object
# Product Sub-Category            object
# Product Container               object
# Product Name                    object
# Product Base Margin            float64
# Region                          object
# State or Province               object
# City                            object
# Postal Code                      int64
# Order Date              datetime64[ns]
# Ship Date               datetime64[ns]
# Profit                         float64
# Quantity ordered new             int64
# Sales                          float64
# Order ID                         int64
# dtype: object

# %%
superstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9426 entries, 0 to 9425
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Row ID                9426 non-null   int64
#  1   Order Priority        9426 non-null   object
#  2   Discount              9426 non-null   float64
#  3   Unit Price            9426 non-null   float64
#  4   Shipping Cost         9426 non-null   float64
#  5   Customer ID           9426 non-null   int64
#  6   Customer Name         9426 non-null   object
#  7   Ship Mode             9426 non-null   object
#  8   Customer Segment      9426 non-null   object
#  9   Product Category      9426 non-null   object
#  10  Product Sub-Category  9426 non-null   object
#  11  Product Container     9426 non-null   object
#  12  Product Name          9426 non-null   object
#  13  Product Base Margin   9354 non-null   float64
#  14  Region                9426 non-null   object
#  15  State or Province     9426 non-null   object
#  16  City                  9426 non-null   object
#  17  Postal Code           9426 non-null   int64
#  18  Order Date            9426 non-null   datetime64[ns]
#  19  Ship Date             9426 non-null   datetime64[ns]
#  20  Profit                9426 non-null   float64
#  21  Quantity ordered new  9426 non-null   int64
#  22  Sales                 9426 non-null   float64
#  23  Order ID              9426 non-null   int64
# dtypes: datetime64[ns](2), float64(6), int64(5), object(11)
# memory usage: 1.7+ MB

# %%
#finding mean, median, mode, count and quartiles(Q1,Q2,Q3,Q4)
superstore_df.describe(include='all')
# Out:
#               Row ID Order Priority     Discount   Unit Price  Shipping Cost  \
# count    9426.000000           9426  9426.000000  9426.000000    9426.000000
# unique           NaN              6          NaN          NaN            NaN
# top              NaN           High          NaN          NaN            NaN
# freq             NaN           1970          NaN          NaN            NaN
# mean    20241.015277            NaN     0.049628    88.303686      12.795142
# min         2.000000            NaN     0.000000     0.990000       0.490000
# 25%     19330.250000            NaN     0.020000     6.480000       3.192500
# 50%     21686.500000            NaN     0.050000    20.990000       6.050000
# 75%     24042.750000            NaN     0.080000    85.990000      13.990000
# max     26399.000000            NaN     0.250000  6783.020000     164.730000
# std      6101.890965            NaN     0.031798   281.540982      17.181203
#
#         Customer ID  Customer Name    Ship Mode Customer Segment  \
# count   9426.000000           9426         9426             9426
# unique          NaN           2703            3                4
# top             NaN  Louis Parrish  Regular Air        Corporate
# freq            NaN             27         7036             3375
# mean    1738.422236            NaN          NaN              NaN
# min        2.000000            NaN          NaN              NaN
# 25%      898.000000            NaN          NaN              NaN
# 50%     1750.000000            NaN          NaN              NaN
# 75%     2578.750000            NaN          NaN              NaN
# max     3403.000000            NaN          NaN              NaN
# std      979.167197            NaN          NaN              NaN
#
#        Product Category  ...   Region State or Province           City  \
# count              9426  ...     9426              9426           9426
# unique                3  ...        4                49           1424
# top     Office Supplies  ...  Central        California  New York City
# freq               5181  ...     2899              1021            202
# mean                NaN  ...      NaN               NaN            NaN
# min                 NaN  ...      NaN               NaN            NaN
# 25%                 NaN  ...      NaN               NaN            NaN
# 50%                 NaN  ...      NaN               NaN            NaN
# 75%                 NaN  ...      NaN               NaN            NaN
# max                 NaN  ...      NaN               NaN            NaN
# std                 NaN  ...      NaN               NaN            NaN
#
#          Postal Code                     Order Date  \
# count    9426.000000                           9426
# unique           NaN                            NaN
# top              NaN                            NaN
# freq             NaN                            NaN
# mean    52446.327286  2012-03-05 18:33:59.465308672
# min      1001.000000            2010-01-01 00:00:00
# 25%     29406.000000            2011-03-07 06:00:00
# 50%     52302.000000            2012-04-08 00:00:00
# 75%     78516.000000            2013-03-26 00:00:00
# max     99362.000000            2013-12-31 00:00:00
# std     29374.597802                            NaN
#
#                             Ship Date        Profit  Quantity ordered new  \
# count                            9426   9426.000000           9426.000000
# unique                            NaN           NaN                   NaN
# top                               NaN           NaN                   NaN
# freq                              NaN           NaN                   NaN
# mean    2012-03-07 19:16:18.485041408    139.236410             13.798430
# min               2010-01-02 00:00:00 -16476.838000              1.000000
# 25%               2011-03-09 00:00:00    -74.017375              5.000000
# 50%               2012-04-09 00:00:00      2.567600             10.000000
# 75%               2013-03-28 00:00:00    140.243850             17.000000
# max               2014-01-17 00:00:00  16332.414000            170.000000
# std                               NaN    998.486483             15.107688
#
#                 Sales      Order ID
# count     9426.000000   9426.000000
# unique            NaN           NaN
# top               NaN           NaN
# freq              NaN           NaN
# mean       949.706272  82318.489073
# min          1.320000      6.000000
# 25%         61.282500  86737.250000
# 50%        203.455000  88344.500000
# 75%        776.402500  89987.750000
# max     100119.160000  91591.000000
# std       2598.019818  19149.448857
#
# [11 rows x 24 columns]

# %%
#Finding missing value

missing_value = superstore_df.isnull().sum()
missing_value
# Out:
# Row ID                   0
# Order Priority           0
# Discount                 0
# Unit Price               0
# Shipping Cost            0
# Customer ID              0
# Customer Name            0
# Ship Mode                0
# Customer Segment         0
# Product Category         0
# Product Sub-Category     0
# Product Container        0
# Product Name             0
# Product Base Margin     72
# Region                   0
# State or Province        0
# City                     0
# Postal Code              0
# Order Date               0
# Ship Date                0
# Profit                   0
# Quantity ordered new     0
# Sales                    0
# Order ID                 0
# dtype: int64

# %% [markdown]
# ### Handling Missing value

# %%
#looking for datatype of 'Product Base Margin' column to find whether to replace it with mean, mode or median

# %%
superstore_df['Product Base Margin'].dtypes
# Out:
# dtype('float64')

# %%
#As the 'Product Base Margin' column is of numerical datatype, lets replace it with median

median_PBM=superstore_df['Product Base Margin'].median
median_PBM()

superstore_df['Product Base Margin']=superstore_df['Product Base Margin'].replace(np.NaN,median_PBM)

# %%
#Looking all Columns after replacing missing values
superstore_df.isnull().sum()
# Out:
# Row ID                  0
# Order Priority          0
# Discount                0
# Unit Price              0
# Shipping Cost           0
# Customer ID             0
# Customer Name           0
# Ship Mode               0
# Customer Segment        0
# Product Category        0
# Product Sub-Category    0
# Product Container       0
# Product Name            0
# Product Base Margin     0
# Region                  0
# State or Province       0
# City                    0
# Postal Code             0
# Order Date              0
# Ship Date               0
# Profit                  0
# Quantity ordered new    0
# Sales                   0
# Order ID                0
# dtype: int64

# %%
# Convert data types if necessary

superstore_df=pd.get_dummies(superstore_df,columns=['Order Priority'])

# %% [markdown]
# #### After converting data type of 'Order Priority'

# %%
superstore_df.head(10)
# Out:
#    Row ID  Discount  Unit Price  Shipping Cost  Customer ID    Customer Name  \
# 0   18606      0.01        2.88           0.50            2  Janice Fletcher
# 1   20847      0.01        2.84           0.93            3    Bonnie Potter
# 2   23086      0.03        6.68           6.15            3    Bonnie Potter
# 3   23087      0.01        5.68           3.60            3    Bonnie Potter
# 4   23088      0.00      205.99           2.50            3    Bonnie Potter
# 5   23597      0.09       55.48          14.30            3    Bonnie Potter
# 6   25549      0.08      120.97          26.30            3    Bonnie Potter
# 7   20228      0.02      500.98          26.00            5   Ronnie Proctor
# 8   19483      0.08        6.48           6.81            5   Ronnie Proctor
# 9   24782      0.01       90.24           0.99            6     Dwight Hwang
#
#         Ship Mode Customer Segment Product Category  \
# 0     Regular Air        Corporate  Office Supplies
# 1     Express Air        Corporate  Office Supplies
# 2     Express Air        Corporate  Office Supplies
# 3     Regular Air        Corporate  Office Supplies
# 4     Express Air        Corporate       Technology
# 5     Express Air        Corporate  Office Supplies
# 6  Delivery Truck        Corporate       Technology
# 7  Delivery Truck      Home Office        Furniture
# 8     Regular Air      Home Office  Office Supplies
# 9     Regular Air      Home Office  Office Supplies
#
#             Product Sub-Category  ...     Profit Quantity ordered new  \
# 0                         Labels  ...     1.3200                    2
# 1            Pens & Art Supplies  ...     4.5600                    4
# 2                          Paper  ...   -47.6400                    7
# 3  Scissors, Rulers and Trimmers  ...   -30.5100                    7
# 4   Telephones and Communication  ...   998.2023                    8
# 5                          Paper  ...  1388.0523                   37
# 6                Office Machines  ...  1001.4453                   12
# 7             Chairs & Chairmats  ...  4390.3665                   12
# 8                          Paper  ...  -141.2600                   18
# 9                     Appliances  ...  1045.4673                   16
#
#      Sales Order ID Order Priority_Critical Order Priority_Critical   \
# 0     5.90    88525                   False                    False
# 1    13.01    88522                   False                    False
# 2    49.92    88523                   False                    False
# 3    41.64    88523                   False                    False
# 4  1446.67    88523                   False                    False
# 5  2011.67    88524                   False                    False
# 6  1451.37    88526                   False                    False
# 7  6362.85    90193                   False                    False
# 8   113.25    90197                   False                    False
# 9  1515.17    90194                   False                    False
#
#    Order Priority_High Order Priority_Low Order Priority_Medium  \
# 0                False              False                 False
# 1                 True              False                 False
# 2                False              False                 False
# 3                False              False                 False
# 4                False              False                 False
# 5                False              False                  True
# 6                False               True                 False
# 7                False              False                 False
# 8                False               True                 False
# 9                 True              False                 False
#
#    Order Priority_Not Specified
# 0                          True
# 1                         False
# 2                          True
# 3                          True
# 4                          True
# 5                         False
# 6                         False
# 7                          True
# 8                         False
# 9                         False
#
# [10 rows x 29 columns]

# %%
superstore_df.dtypes
# Out:
# Row ID                                   int64
# Discount                               float64
# Unit Price                             float64
# Shipping Cost                          float64
# Customer ID                              int64
# Customer Name                           object
# Ship Mode                               object
# Customer Segment                        object
# Product Category                        object
# Product Sub-Category                    object
# Product Container                       object
# Product Name                            object
# Product Base Margin                     object
# Region                                  object
# State or Province                       object
# City                                    object
# Postal Code                              int64
# Order Date                      datetime64[ns]
# Ship Date                       datetime64[ns]
# Profit                                 float64
# Quantity ordered new                     int64
# Sales                                  float64
# Order ID                                 int64
# Order Priority_Critical                   bool
# Order Priority_Critical                   bool
# Order Priority_High                       bool
# Order Priority_Low                        bool
# Order Priority_Medium                     bool
# Order Priority_Not Specified              bool
# dtype: object

# %%
# Univariate analysis of sales distribution
plt.figure(figsize=(10,8))
sns.histplot(superstore_df['Sales'])
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Count')
plt.show()


# Bivariate analysis profit against sales
plt.figure(figsize=(10,8))
sns.scatterplot(superstore_df,x='Sales',y='Profit')
plt.title('Sales Vs Profit Scatterplot')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ### Summary statistics for key Variables

# %%
# Summary statistics for key variables
Summary_Stats = superstore_df[['Sales','Profit','Quantity ordered new','Discount']].describe()
Summary_Stats
# Out:
#                Sales        Profit  Quantity ordered new     Discount
# count    9426.000000   9426.000000           9426.000000  9426.000000
# mean      949.706272    139.236410             13.798430     0.049628
# std      2598.019818    998.486483             15.107688     0.031798
# min         1.320000 -16476.838000              1.000000     0.000000
# 25%        61.282500    -74.017375              5.000000     0.020000
# 50%       203.455000      2.567600             10.000000     0.050000
# 75%       776.402500    140.243850             17.000000     0.080000
# max    100119.160000  16332.414000            170.000000     0.250000

# %% [markdown]
# ### Grouped statistics

# %%
Regionwise_sales = superstore_df.groupby('Region')['Sales'].sum()
Regionwise_sales
# Out:
# Region
# Central    2540341.62
# East       2422804.68
# South      1597346.22
# West       2391438.80
# Name: Sales, dtype: float64

# %% [markdown]
# ### Conclusion
#
# - Summary of key findings.
# - Insights based on the analysis.

# %% [markdown]
# ## Additional Statistical Analysis

# %%
from scipy.stats import ttest_ind, chi2_contingency

# Example: T-test for sales in different regions
region1_sales = superstore_df[superstore_df['Region'] == 'Central']['Sales']
region2_sales = superstore_df[superstore_df['Region'] == 'East']['Sales']

t_stat, p_value=ttest_ind(region1_sales,region2_sales,equal_var =False)
print(f'T-Stats is:{t_stat}')
print(f'p_value is:{p_value}')

# Example: Chi-square test for independence between Ship Mode and Customer Segment
contingency_table = pd.crosstab(superstore_df['Product Category'],superstore_df['Region'])
chi2_stat, p_value,dof, expected=chi2_contingency(contingency_table)
print(f'Chi-Square test result:{chi2_stat}')
print(f'p_value is:{p_value}')
# Out:
# T-Stats is:-2.610741590032512
# p_value is:0.009067947578260096
# Chi-Square test result:6.869902178541711
# p_value is:0.333046426277668

# %%
# Selecting only numeric columns for correlation matrix

sns.heatmap(superstore_df.corr(numeric_only=True),annot=True,fmt=".1f",cmap='coolwarm')
plt.title('Correlation Matrix')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix')

# %% [markdown]
# ### Sales and profit trend over period of time

# %%
# Plotting sales trends over time
superstore_df['Order Date'] = pd.to_datetime(superstore_df['Order Date'])
superstore_df.set_index('Order Date', inplace=True)

# Resample sales data by month
monthly_sales = superstore_df['Sales'].resample('M').sum()

monthly_sales.plot(kind='line', figsize=(12, 6))
plt.title('Monthly Sales Trend')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Plotting profit trends over time
profit_over_time = superstore_df['Profit'].resample('M').sum()
profit_over_time.plot(kind='line', figsize=(12, 6))
plt.title('Profit Trends Over Time')
plt.xlabel('Date')
plt.ylabel('Profit')
plt.show()

# %%
# Identifying top-performing product categories based on total sales and profit
top_sales_cat = superstore_df.groupby('Product Category')['Sales'].sum()
top_profit_cat = superstore_df.groupby('Product Category')['Profit'].sum()

# Plotting total sales by product category
sns.barplot(x=top_sales_cat.index, y=top_sales_cat.values)
plt.title('Top performing product by sales')
plt.xlabel('Product Category')
plt.ylabel('Sales')
plt.show()

# Plotting total Profit by product category
sns.barplot(x=top_profit_cat.index, y=top_profit_cat.values)
plt.title('Top Profit by Product')
plt.xlabel('Product Category')
plt.ylabel('Profit')
plt.show()

Pro_cat_sales_Profit=superstore_df.groupby('Product Category')[['Sales','Profit']].sum()
Pro_cat_sales_Profit
# Out:
#                        Sales         Profit
# Product Category
# Furniture         3178623.74  177354.298188
# Office Supplies   2258325.55  451990.216492
# Technology        3514982.03  683097.884748

# %% [markdown]
# # Not Covered (out of syllabus)

# %%
# Generating summary statistics for each region


# Display summary statistics

# %%
# Visualizing the correlation between sales and profit
sns.scatterplot(data=superstore_df, x='Sales',y='Profit')
plt.title('correlation between sales and profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# Displaying the correlation coefficient
correlation = superstore_df[['Sales','Profit']].corr()
print('Correlation coefficient between sales and profit\n',correlation)
# Out:
# Correlation coefficient between sales and profit
#             Sales    Profit
# Sales   1.000000  0.371583
# Profit  0.371583  1.000000

# %%
# Analyzing seasonal sales trends

# Grouping sales data by month and year

# Plotting seasonal sales trends

# %%
# Comparing sales across different ship modes

sales_by_ship_mode = superstore_df.groupby('Ship Mode')['Sales'].sum()

# Plotting sales by ship mode
sales_by_ship_mode.plot(kind='bar', figsize=(12, 6))
plt.title('Sales by Ship Mode')
plt.xlabel('Ship Mode')
plt.ylabel('Total Sales')
plt.show()

# %%
# Ensure column names are clean

# Print column names to verify

# Ensure 'Ship Date' column is datetime type

# Dropping rows where 'Ship Date' couldn't be converted

# Resample sales data by month
